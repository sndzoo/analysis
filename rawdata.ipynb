# %% [markdown]
# # Raw Data

# %%
import pandas as pd
dfs = dict()
dfs["sec01"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_sec01/data/csv_experiments.csv")
dfs["sec02"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_sec02/data/csv_experiments.csv")
dfs["sec03"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_sec03/data/csv_experiments.csv")

dfs["web01"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_web01/data/csv_experiments.csv")
dfs["web02"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_web02/data/csv_experiments.csv")
dfs["web03"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_web03/data/csv_experiments.csv")

dfs["iot01"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_iot01/data/csv_experiments.csv")
dfs["iot02"] = pd.read_csv("/home/manuel/sndzoo/ds_nfv_iot02/data/csv_experiments.csv")

# %% [markdown]
# ## Column Names

# %%
for k, d in dfs.items():
    print("\n"*3)
    print("*************** {} ***************".format(k))
    for cn in list(d):
        print(cn)
# Out:
# *************** sec01 ***************
# Unnamed: 0
# experiment_name
# experiment_start
# experiment_stop
# metric__mp.input.vdu01.0__stat__data__collisions
# metric__mp.input.vdu01.0__stat__data__multicast
# metric__mp.input.vdu01.0__stat__data__rx_bytes
# metric__mp.input.vdu01.0__stat__data__rx_compressed
# metric__mp.input.vdu01.0__stat__data__rx_crc_errors
# metric__mp.input.vdu01.0__stat__data__rx_dropped
# metric__mp.input.vdu01.0__stat__data__rx_errors
# metric__mp.input.vdu01.0__stat__data__rx_fifo_errors
# metric__mp.input.vdu01.0__stat__data__rx_frame_errors
# metric__mp.input.vdu01.0__stat__data__rx_length_errors
# metric__mp.input.vdu01.0__stat__data__rx_missed_errors
# metric__mp.input.vdu01.0__stat__data__rx_over_errors
# metric__mp.input.vdu01.0__stat__data__rx_packets
# metric__mp.input.vdu01.0__stat__data__tx_aborted_errors
# metric__mp.input.vdu01.0__stat__data__tx_bytes
# metric__mp.input.vdu01.0__stat__data__tx_carrier_errors
# ...
